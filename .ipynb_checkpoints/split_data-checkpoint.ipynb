# %%
import os
import random

data_path = "data/ishihara"
file_names = os.listdir(data_path)

# %%
test_files = random.sample(file_names, int(len(file_names) * 0.2))
test_files = random.sample(file_names, len(file_names) - int(len(file_names) * 0.2))
# Out:
# ['9_Imprima-Regulartheme_4 type_3.png',
#  '3_Varela-Regulartheme_4 type_3.png',
#  '7_Spectral-Mediumtheme_2 type_2.png',
#  '2_Exo-BlackItalictheme_4 type_3.png',
#  '4_Waree-Obliquetheme_2 type_2.png',
#  '5_DejaVuSansCondensed-Obliquetheme_3 type_3.png',
#  '7_DejaVuSansCondensed-Obliquetheme_3 type_3.png',
#  '0_Asap-MediumItalictheme_4 type_3.png',
#  '7_K2D-Lighttheme_4 type_3.png',
#  '0_AveriaSerifLibre-Regulartheme_4 type_3.png',
#  '9_Mate-Regulartheme_4 type_3.png',
#  '6_Exo-BlackItalictheme_1 type_1.png',
#  '7_Imprima-Regulartheme_2 type_2.png',
#  '0_DejaVuSanstheme_4 type_3.png',
#  '1_Chilanka-Regulartheme_3 type_3.png',
#  '4_SpectralSC-ExtraBoldItalictheme_4 type_3.png',
#  '1_BalooThambi-Regulartheme_4 type_3.png',
#  '1_BalooThambi-Regulartheme_2 type_2.png',
#  '7_SpectralSC-ExtraBoldItalictheme_3 type_3.png',
#  '1_DejaVuSanstheme_2 type_2.png',
#  '7_ChangaOne-Regulartheme_1 type_1.png',
#  '0_Ramaraja-Regulartheme_1 type_1.png',
# ...
